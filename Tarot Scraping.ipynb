# %%
# v0.1 by Victor Schetinger
# Notebook to test a full pipeline of extraction-processing-vis of textual information
# Data mined from http://www.learntarot.com
# D3 js copied from http://bl.ocks.org/mbostock/1153292

# %%
# Importing all stuff
import requests
import html2text
import pprint
import re
import pandas as pd
from IPython.core.display import HTML, display
from string import Template
import json

# %%
# Defines the order of the cards
major_arcana_ordered = [u'THE FOOL',u'THE MAGICIAN',u'THE HIGH PRIESTESS',u'THE EMPRESS',u'THE EMPEROR',u'THE HIEROPHANT',
                        u'THE LOVERS',u'THE CHARIOT',u'STRENGTH',u'THE HERMIT',u'JUSTICE',u'WHEEL OF FORTUNE',u'THE HANGED MAN',
                        u'DEATH',u'TEMPERANCE',u'THE DEVIL',u'THE TOWER',u'THE STAR',u'THE MOON',u'THE SUN',
                        u'JUDGEMENT',u'THE WORLD']

# Fixes the difference in card names
def fixT(cardname):
    if cardname.upper() in major_arcana_ordered:
        return cardname.upper()
    else:
        # Bugado pra minor arcana
        return u'THE ' + cardname.upper()

# %%
# Generates urls for content extraction
urls =  ['http://www.learntarot.com/maj0' + str(i) + '.htm' for i in range(0,10)]
urls += ['http://www.learntarot.com/maj' + str(i) + '.htm' for i in range(10,22)]
# Extracts html for major arcana
htmls = [requests.get(url).content for url in urls]

# %%
# Clears all tags
texts = [html2text.html2text(html) for html in htmls]

# %%
# Extract card titles
card = re.search(r'\#\s([\w\s]*)\n\n', texts[6]).groups()[0]
print(card)

# Extracts card associations
association = re.findall(r'\*\s\*\*([\w\s]*)\*\*', texts[6])
print(association)
opposing = re.findall(r'\[([\w\s]+)\]', re.findall(r'\(howcard\.htm\#howopposite\).*REINFORCING', texts[6],re.DOTALL)[0],re.DOTALL)
print(opposing)
reinforcing = re.findall(r'\[([\w\s]+)\]', re.findall(r'\(howcard\.htm\#howreinforce\).*\[DESCR', texts[6],re.DOTALL)[0],re.DOTALL)
print(reinforcing)
# Out:
# THE LOVERS
# [u'RELATIONSHIP', u'SEXUALITY', u'PERSONAL BELIEFS', u'VALUES']
# [u'Hierophant', u'Hermit', u'Five of Cups', u'Three of Swords']
# [u'Empress', u'Two of Cups', u'Nine of Cups', u'Ten of Cups', u'Ten of Pentacles']

# %%
# Space to save useful regexps
#[cards_and_associations[card]['Number'] for card in cards_and_associations]
#[[text[1],re.findall(r'Some Possibilities\].*\[REIN', text[0],re.DOTALL)] for text in zip(texts,range(0,22)) ]
#[re.findall(r'\[([\w\s]+)\]', re.findall(r'Some Possibilities\].*\[REIN', text[0],re.DOTALL)[0],re.DOTALL) for text in zip(texts,range(0,22))]

# %%
#Creates the dictionary of cards and associations
cards_and_associations = {re.search(r'\#\s([\w\s]*)\n\n', text[0]).groups()[0] : 
                          {'Number'       : text[1],
                           'Associations' : re.findall(r'\*\s\*\*([\w\s]*)\*\*', text[0]),
                           'Opposing'     : re.findall(r'\[([\w\s]+)\]', re.findall(r'\(howcard\.htm\#howopposite\).*REINFORCING', text[0],re.DOTALL)[0],re.DOTALL),
                           'Reinforcing'  : re.findall(r'\[([\w\s]+)\]', re.findall(r'\(howcard\.htm\#howreinforce\).*\[DESCR', text[0],re.DOTALL)[0],re.DOTALL)} 
                          for text in zip(texts,range(0,22))}
cards_and_associations
# Out:
# {u'DEATH': {'Associations': [u'ENDING',
#    u'TRANSITION',
#    u'ELIMINATION',
#    u'INEXORABLE FORCES'],
#   'Number': 13,
#   'Opposing': [u'Fool', u'Empress', u'Judgement'],
#   'Reinforcing': [u'Tower',
#    u'Eight of Wands',
#    u'Five of Cups',
#    u'Eight of Cups']},
#  u'JUDGEMENT': {'Associations': [u'JUDGMENT',
#    u'REBIRTH',
#    u'INNER CALLING',
#    u'ABSOLUTION'],
#   'Number': 20,
#   'Opposing': [u'Death', u'Five of Cups', u'Nine of Swords'],
#   'Reinforcing': [u'Fool', u'Justice', u'Seven of Pentacles']},
#  u'JUSTICE': {'Associations': [u'JUSTICE',
#    u'RESPONSIBILITY',
#    u'DECISION',
#    u'CAUSE AND EFFECT'],
#   'Number': 11,
#   'Opposing': [u'Two of Swords', u'Five of Swords', u'Seven of Swords'],
#   'Reinforcing': [u'Emperor',
#    u'Judgement',
#    u'Ten of Wands',
#    u'Nine of Swords',
#    u'Seven of Pentacles']},
#  u'STRENGTH': {'Associations': [u'STRENGTH',
#    u'PATIENCE',
#    u'COMPASSION',
#    u'SOFT CONTROL'],
#   'Number': 8,
#   'Opposing': [u'Chariot',
#    u'Eight of Cups',
#    u'Six of Swords',
#    u'Five of Pentacles'],
#   'Reinforcing': [u'Hanged Man', u'Nine of Wands']},
#  u'TEMPERANCE': {'Associations': [u'TEMPERANCE',
#    u'BALANCE',
#    u'HEALTH',
#    u'COMBINATION'],
#   'Number': 14,
#   'Opposing': [u'Tower',
#    u'Five of Wands',
#    u'Seven of Cups',
#    u'Five of Swords',
#    u'Five of Pentacles'],
#   'Reinforcing': [u'World',
#    u'Two of Cups',
#    u'Three of Cups',
#    u'Two of Pentacles',
#    u'Three of Pentacles']},
#  u'THE CHARIOT': {'Associations': [u'VICTORY', u'WILL', u'HARD CONTROL'],
#   'Number': 7,
#   'Opposing': [u'Strength',
#    u'Hanged Man',
#    u'Tower',
#    u'Eight of Swords',
#    u'Ten of Swords'],
#   'Reinforcing': [u'Magician',
#    u'Two of Wands',
#    u'Six of Wands',
#    u'Four of Pentacles',
#    u'Nine of Pentacles']},
#  u'THE DEVIL': {'Associations': [u'BONDAGE',
#    u'MATERIALISM',
#    u'IGNORANCE',
#    u'HOPELESSNESS'],
#   'Number': 15,
#   'Opposing': [u'Fool',
#    u'Star',
#    u'Four of Wands',
#    u'Six of Cups',
#    u'Ten of Cups'],
#   'Reinforcing': [u'Seven of Cups', u'Eight of Swords', u'Nine of Swords']},
#  u'THE EMPEROR': {'Associations': [u'FATHERING',
#    u'STRUCTURE',
#    u'AUTHORITY',
#    u'REGULATION'],
#   'Number': 4,
#   'Opposing': [u'Empress', u'Seven of Cups', u'Five of Swords'],
#   'Reinforcing': [u'Hierophant',
#    u'Justice',
#    u'Two of Wands',
#    u'Three of Wands',
#    u'Four of Pentacles']},
#  u'THE EMPRESS': {'Associations': [u'MOTHERING',
#    u'ABUNDANCE',
#    u'SENSES',
#    u'NATURE'],
#   'Number': 3,
#   'Opposing': [u'Emperor',
#    u'Death',
#    u'Four of Pentacles',
#    u'Nine of Pentacles'],
#   'Reinforcing': [u'Lovers',
#    u'Star',
#    u'Nine of Cups',
#    u'Seven of Pentacles',
#    u'Ten of Pentacles']},
#  u'THE FOOL': {'Associations': [u'BEGINNING',
#    u'SPONTANEITY',
#    u'FAITH',
#    u'APPARENT FOLLY'],
#   'Number': 0,
#   'Opposing': [u'Hierophant',
#    u'Death',
#    u'Devil',
#    u'Two of Swords',
#    u'Four of Pentacles'],
#   'Reinforcing': [u'Hanged Man', u'Star', u'Judgement', u'Three of Wands']},
#  u'THE HANGED MAN': {'Associations': [u'LETTING GO',
#    u'REVERSAL',
#    u'SUSPENSION',
#    u'SACRIFICE'],
#   'Number': 12,
#   'Opposing': [u'Magician',
#    u'Chariot',
#    u'Seven of Wands',
#    u'Ten of Wands',
#    u'Four of Pentacles'],
#   'Reinforcing': [u'Fool',
#    u'High Priestess',
#    u'Strength',
#    u'Four of Swords',
#    u'Ten of Swords']},
#  u'THE HERMIT': {'Associations': [u'INTROSPECTION',
#    u'SEARCHING',
#    u'GUIDANCE',
#    u'SOLITUDE'],
#   'Number': 9,
#   'Opposing': [u'Lovers',
#    u'World',
#    u'Two of Cups',
#    u'Three of Cups',
#    u'Nine of Cups'],
#   'Reinforcing': [u'High Priestess',
#    u'Four of Cups',
#    u'Eight of Cups',
#    u'Four of Swords',
#    u'Seven of Swords']},
#  u'THE HIEROPHANT': {'Associations': [u'EDUCATION',
#    u'BELIEF SYSTEMS',
#    u'CONFORMITY',
#    u'GROUP IDENTIFICATION'],
#   'Number': 5,
#   'Opposing': [u'Fool',
#    u'Lovers',
#    u'Two of Wands',
#    u'Seven of Swords',
#    u'Two of Pentacles'],
#   'Reinforcing': [u'Emperor',
#    u'Three of Cups',
#    u'Three of Pentacles',
#    u'Eight of Pentacles',
#    u'Ten of Pentacles']},
#  u'THE HIGH PRIESTESS': {'Associations': [u'NONACTION',
#    u'UNCONSCIOUS AWARENESS',
#    u'POTENTIAL',
#    u'MYSTERY'],
#   'Number': 2,
#   'Opposing': [u'Magician',
#    u'Two of Wands',
#    u'Seven of Wands',
#    u'Eight of Wands'],
#   'Reinforcing': [u'Hermit', u'Hanged Man', u'Four of Swords']},
#  u'THE LOVERS': {'Associations': [u'RELATIONSHIP',
#    u'SEXUALITY',
#    u'PERSONAL BELIEFS',
#    u'VALUES'],
#   'Number': 6,
#   'Opposing': [u'Hierophant', u'Hermit', u'Five of Cups', u'Three of Swords'],
#   'Reinforcing': [u'Empress',
#    u'Two of Cups',
#    u'Nine of Cups',
#    u'Ten of Cups',
#    u'Ten of Pentacles']},
#  u'THE MAGICIAN': {'Associations': [u'ACTION',
#    u'CONSCIOUS AWARENESS',
#    u'CONCENTRATION',
#    u'POWER'],
#   'Number': 1,
#   'Opposing': [u'High Priestess',
#    u'Hanged Man',
#    u'Seven of Cups',
#    u'Four of Swords',
#    u'Eight of Swords'],
#   'Reinforcing': [u'Chariot',
#    u'Two of Wands',
#    u'Eight of Wands',
#    u'Eight of Pentacles']},
#  u'THE MOON': {'Associations': [u'FEAR',
#    u'ILLUSION',
#    u'IMAGINATION',
#    u'BEWILDERMENT'],
#   'Number': 18,
#   'Opposing': [u'Star', u'Sun'],
#   'Reinforcing': [u'Seven of Cups', u'Two of Swords', u'Eight of Swords']},
#  u'THE STAR': {'Associations': [u'HOPE',
#    u'INSPIRATION',
#    u'GENEROSITY',
#    u'SERENITY'],
#   'Number': 17,
#   'Opposing': [u'Devil',
#    u'Tower',
#    u'Moon',
#    u'Two of Swords',
#    u'Nine of Swords'],
#   'Reinforcing': [u'Fool', u'Empress', u'Six of Cups', u'Ten of Cups']},
#  u'THE SUN': {'Associations': [u'ENLIGHTENMENT',
#    u'GREATNESS',
#    u'VITALITY',
#    u'ASSURANCE'],
#   'Number': 19,
#   'Opposing': [u'Moon',
#    u'Eight of Cups',
#    u'Six of Swords',
#    u'Five of Pentacles'],
#   'Reinforcing': [u'Tower', u'World', u'Two of Wands', u'Six of Wands']},
#  u'THE TOWER': {'Associations': [u'SUDDEN CHANGE',
#    u'RELEASE',
#    u'DOWNFALL',
#    u'REVELATION'],
#   'Number': 16,
#   'Opposing': [u'Chariot',
#    u'Temperance',
#    u'Star',
#    u'Six of Wands',
#    u'Ten of Cups'],
#   'Reinforcing': [u'Death', u'Sun', u'Five of Pentacles']},
#  u'THE WORLD': {'Associations': [u'INTEGRATION',
#    u'ACCOMPLISHMENT',
#    u'INVOLVEMENT',
#    u'FULFILLMENT'],
#   'Number': 21,
#   'Opposing': [u'Hermit', u'Four of Cups', u'Five of Wands'],
#   'Reinforcing': [u'Temperance',
#    u'Sun',
#    u'Nine of Cups',
#    u'Ten of Cups',
#    u'Ten of Pentacles']},
#  u'WHEEL OF FORTUNE': {'Associations': [u'DESTINY',
#    u'TURNING POINT',
#    u'MOVEMENT',
#    u'PERSONAL VISION'],
#   'Number': 10,
#   'Opposing': [u'Two of Swords',
#    u'Four of Swords',
#    u'Four of Pentacles',
#    u'Seven of Pentacles'],
#   'Reinforcing': [u'Eight of Wands']}}

# %%
# Creates the Panda Container
df = pd.DataFrame({'Number'      : [cards_and_associations[card]['Number'] for card in cards_and_associations], 
                   'Card'        : [card for card in cards_and_associations], 
                   'Associations': [cards_and_associations[card]['Associations'] for card in cards_and_associations],
                   'Opposing'    : [cards_and_associations[card]['Opposing'] for card in cards_and_associations],
                   'Reinforcing' : [cards_and_associations[card]['Reinforcing'] for card in cards_and_associations]})

# %%
df = df.sort_values('Number', ascending=True).reset_index().drop(columns='index')
cols = ['Number','Card','Associations','Opposing','Reinforcing']
df[cols]
# Out:
#     Number                Card  \
# 0        0            THE FOOL
# 1        1        THE MAGICIAN
# 2        2  THE HIGH PRIESTESS
# 3        3         THE EMPRESS
# 4        4         THE EMPEROR
# 5        5      THE HIEROPHANT
# 6        6          THE LOVERS
# 7        7         THE CHARIOT
# 8        8            STRENGTH
# 9        9          THE HERMIT
# 10      10    WHEEL OF FORTUNE
# 11      11             JUSTICE
# 12      12      THE HANGED MAN
# 13      13               DEATH
# 14      14          TEMPERANCE
# 15      15           THE DEVIL
# 16      16           THE TOWER
# 17      17            THE STAR
# 18      18            THE MOON
# 19      19             THE SUN
# 20      20           JUDGEMENT
# 21      21           THE WORLD
#
#                                          Associations  \
# 0     [BEGINNING, SPONTANEITY, FAITH, APPARENT FOLLY]
# 1   [ACTION, CONSCIOUS AWARENESS, CONCENTRATION, P...
# 2   [NONACTION, UNCONSCIOUS AWARENESS, POTENTIAL, ...
# 3              [MOTHERING, ABUNDANCE, SENSES, NATURE]
# 4       [FATHERING, STRUCTURE, AUTHORITY, REGULATION]
# 5   [EDUCATION, BELIEF SYSTEMS, CONFORMITY, GROUP ...
# 6   [RELATIONSHIP, SEXUALITY, PERSONAL BELIEFS, VA...
# 7                       [VICTORY, WILL, HARD CONTROL]
# 8      [STRENGTH, PATIENCE, COMPASSION, SOFT CONTROL]
# 9      [INTROSPECTION, SEARCHING, GUIDANCE, SOLITUDE]
# 10  [DESTINY, TURNING POINT, MOVEMENT, PERSONAL VI...
# 11  [JUSTICE, RESPONSIBILITY, DECISION, CAUSE AND ...
# 12      [LETTING GO, REVERSAL, SUSPENSION, SACRIFICE]
# 13  [ENDING, TRANSITION, ELIMINATION, INEXORABLE F...
# 14         [TEMPERANCE, BALANCE, HEALTH, COMBINATION]
# 15    [BONDAGE, MATERIALISM, IGNORANCE, HOPELESSNESS]
# 16     [SUDDEN CHANGE, RELEASE, DOWNFALL, REVELATION]
# 17          [HOPE, INSPIRATION, GENEROSITY, SERENITY]
# 18        [FEAR, ILLUSION, IMAGINATION, BEWILDERMENT]
# 19    [ENLIGHTENMENT, GREATNESS, VITALITY, ASSURANCE]
# 20     [JUDGMENT, REBIRTH, INNER CALLING, ABSOLUTION]
# 21  [INTEGRATION, ACCOMPLISHMENT, INVOLVEMENT, FUL...
#
#                                              Opposing  \
# 0   [Hierophant, Death, Devil, Two of Swords, Four...
# 1   [High Priestess, Hanged Man, Seven of Cups, Fo...
# 2   [Magician, Two of Wands, Seven of Wands, Eight...
# 3   [Emperor, Death, Four of Pentacles, Nine of Pe...
# 4            [Empress, Seven of Cups, Five of Swords]
# 5   [Fool, Lovers, Two of Wands, Seven of Swords, ...
# 6   [Hierophant, Hermit, Five of Cups, Three of Sw...
# 7   [Strength, Hanged Man, Tower, Eight of Swords,...
# 8   [Chariot, Eight of Cups, Six of Swords, Five o...
# 9   [Lovers, World, Two of Cups, Three of Cups, Ni...
# 10  [Two of Swords, Four of Swords, Four of Pentac...
# 11   [Two of Swords, Five of Swords, Seven of Swords]
# 12  [Magician, Chariot, Seven of Wands, Ten of Wan...
# 13                         [Fool, Empress, Judgement]
# 14  [Tower, Five of Wands, Seven of Cups, Five of ...
# 15  [Fool, Star, Four of Wands, Six of Cups, Ten o...
# 16  [Chariot, Temperance, Star, Six of Wands, Ten ...
# 17  [Devil, Tower, Moon, Two of Swords, Nine of Sw...
# 18                                        [Star, Sun]
# 19  [Moon, Eight of Cups, Six of Swords, Five of P...
# 20              [Death, Five of Cups, Nine of Swords]
# 21              [Hermit, Four of Cups, Five of Wands]
#
#                                           Reinforcing
# 0       [Hanged Man, Star, Judgement, Three of Wands]
# 1   [Chariot, Two of Wands, Eight of Wands, Eight ...
# 2                [Hermit, Hanged Man, Four of Swords]
# 3   [Lovers, Star, Nine of Cups, Seven of Pentacle...
# 4   [Hierophant, Justice, Two of Wands, Three of W...
# 5   [Emperor, Three of Cups, Three of Pentacles, E...
# 6   [Empress, Two of Cups, Nine of Cups, Ten of Cu...
# 7   [Magician, Two of Wands, Six of Wands, Four of...
# 8                         [Hanged Man, Nine of Wands]
# 9   [High Priestess, Four of Cups, Eight of Cups, ...
# 10                                   [Eight of Wands]
# 11  [Emperor, Judgement, Ten of Wands, Nine of Swo...
# 12  [Fool, High Priestess, Strength, Four of Sword...
# 13  [Tower, Eight of Wands, Five of Cups, Eight of...
# 14  [World, Two of Cups, Three of Cups, Two of Pen...
# 15   [Seven of Cups, Eight of Swords, Nine of Swords]
# 16                    [Death, Sun, Five of Pentacles]
# 17          [Fool, Empress, Six of Cups, Ten of Cups]
# 18    [Seven of Cups, Two of Swords, Eight of Swords]
# 19         [Tower, World, Two of Wands, Six of Wands]
# 20                [Fool, Justice, Seven of Pentacles]
# 21  [Temperance, Sun, Nine of Cups, Ten of Cups, T...

# %%
# Template for the d2 js graph visualization
html_template = '''
<!DOCTYPE html>
<meta charset="utf-8">
<style>

.link {
  fill: none;
  stroke: #666;
  stroke-width: 1.5px;
}

#licensing {
  fill: green;
}

.link.licensing {
  stroke: green;
}

.link.resolved {
  stroke-dasharray: 0,2 1;
}

circle {
  fill: #ccc;
  stroke: #333;
  stroke-width: 1.5px;
}

text {
  font: 10px sans-serif;
  pointer-events: none;
  text-shadow: 0 1px 0 #fff, 1px 0 0 #fff, 0 -1px 0 #fff, -1px 0 0 #fff;
}

</style>
<body>
<script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
<script>

var links =  $tarot_links ;

var nodes = {};

// Compute the distinct nodes from the links.
links.forEach(function(link) {
  link.source = nodes[link.source] || (nodes[link.source] = {name: link.source});
  link.target = nodes[link.target] || (nodes[link.target] = {name: link.target});
});

var width = 960,
    height = 500;

var force = d3.layout.force()
    .nodes(d3.values(nodes))
    .links(links)
    .size([width, height])
    .linkDistance(60)
    .charge(-300)
    .on("tick", tick)
    .start();

var svg = d3.select("#graph").append("svg")
    .attr("width", width)
    .attr("height", height);

// Per-type markers, as they don't inherit styles.
svg.append("defs").selectAll("marker")
    .data(["suit", "licensing", "resolved"])
  .enter().append("marker")
    .attr("id", function(d) { return d; })
    .attr("viewBox", "0 -5 10 10")
    .attr("refX", 15)
    .attr("refY", -1.5)
    .attr("markerWidth", 6)
    .attr("markerHeight", 6)
    .attr("orient", "auto")
  .append("path")
    .attr("d", "M0,-5L10,0L0,5");

var path = svg.append("g").selectAll("path")
    .data(force.links())
  .enter().append("path")
    .attr("class", function(d) { return "link " + d.type; })
    .attr("marker-end", function(d) { return "url(#" + d.type + ")"; });

var circle = svg.append("g").selectAll("circle")
    .data(force.nodes())
  .enter().append("circle")
    .attr("r", 6)
    .call(force.drag);

var text = svg.append("g").selectAll("text")
    .data(force.nodes())
  .enter().append("text")
    .attr("x", 8)
    .attr("y", ".31em")
    .text(function(d) { return d.name; });

// Use elliptical arc path segments to doubly-encode directionality.
function tick() {
  path.attr("d", linkArc);
  circle.attr("transform", transform);
  text.attr("transform", transform);
}

function linkArc(d) {
  var dx = d.target.x - d.source.x,
      dy = d.target.y - d.source.y,
      dr = Math.sqrt(dx * dx + dy * dy);
  return "M" + d.source.x + "," + d.source.y + "A" + dr + "," + dr + " 0 0,1 " + d.target.x + "," + d.target.y;
}

function transform(d) {
  return "translate(" + d.x + "," + d.y + ")";
}

</script>
'''

# %%
# Builds the data for card links
links_opposing = [[{'source'        : card, 
          'target': fixT(target) ,
          'type'    : 'licensing'} for target in cards_and_associations[card]['Opposing'] ]
                                     for card in cards_and_associations ]# links
links_opposing = [j for i in links_opposing for j in i]
links_reinforcing = [[{'source'        : card, 
          'target': fixT(target) ,
          'type'    : 'suit'} for target in cards_and_associations[card]['Reinforcing']]
                                     for card in cards_and_associations]# links
links_reinforcing = [j for i in links_reinforcing for j in i]

links_order = [{'source'  : major_arcana_ordered[i], 
                'target'  : major_arcana_ordered[i+1],
                'type'    : 'resolved'} for i in range(0,len(major_arcana_ordered)-1)]
                                    

links = links_opposing + links_reinforcing + links_order
links = [link for link in links if link['target'] in major_arcana_ordered]

# %%
# Injects data into the original template
js_text_template = Template(html_template)
filled_template = js_text_template.substitute({"tarot_links":json.dumps(links)})#html_template.replace(u'$tarot_links',links.__str__())
print(filled_template)
# Out:
# <!DOCTYPE html>
# <meta charset="utf-8">
# <style>
#
# .link {
#   fill: none;
#   stroke: #666;
#   stroke-width: 1.5px;
# }
#
# #licensing {
#   fill: green;
# }
#
# .link.licensing {
#   stroke: green;
# }
#
# .link.resolved {
#   stroke-dasharray: 0,2 1;
# }
#
# circle {
#   fill: #ccc;
#   stroke: #333;
#   stroke-width: 1.5px;
# }
#
# text {
#   font: 10px sans-serif;
#   pointer-events: none;
#   text-shadow: 0 1px 0 #fff, 1px 0 0 #fff, 0 -1px 0 #fff, -1px 0 0 #fff;
# }
#
# </style>
# <body>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <script>
#
# var links =  [{"source": "DEATH", "type": "licensing", "target": "THE FOOL"}, {"source": "DEATH", "type": "licensing", "target": "THE EMPRESS"}, {"source": "DEATH", "type": "licensing", "target": "JUDGEMENT"}, {"source": "THE EMPRESS", "type": "licensing", "target": "THE EMPEROR"}, {"source": "THE EMPRESS", "type": "licensing", "target": "DEATH"}, {"source": "STRENGTH", "type": "licensing", "target": "THE CHARIOT"}, {"source": "THE LOVERS", "type": "licensing", "target": "THE HIEROPHANT"}, {"source": "THE LOVERS", "type": "licensing", "target": "THE HERMIT"}, {"source": "JUDGEMENT", "type": "licensing", "target": "DEATH"}, {"source": "THE MAGICIAN", "type": "licensing", "target": "THE HIGH PRIESTESS"}, {"source": "THE MAGICIAN", "type": "licensing", "target": "THE HANGED MAN"}, {"source": "THE HANGED MAN", "type": "licensing", "target": "THE MAGICIAN"}, {"source": "THE HANGED MAN", "type": "licensing", "target": "THE CHARIOT"}, {"source": "THE HIEROPHANT", "type": "licensing", "target": "THE FOOL"}, {"source": "THE HIEROPHANT", "type": "licensing", "target": "THE LOVERS"}, {"source": "THE CHARIOT", "type": "licensing", "target": "STRENGTH"}, {"source": "THE CHARIOT", "type": "licensing", "target": "THE HANGED MAN"}, {"source": "THE CHARIOT", "type": "licensing", "target": "THE TOWER"}, {"source": "TEMPERANCE", "type": "licensing", "target": "THE TOWER"}, {"source": "THE FOOL", "type": "licensing", "target": "THE HIEROPHANT"}, {"source": "THE FOOL", "type": "licensing", "target": "DEATH"}, {"source": "THE FOOL", "type": "licensing", "target": "THE DEVIL"}, {"source": "THE HIGH PRIESTESS", "type": "licensing", "target": "THE MAGICIAN"}, {"source": "THE SUN", "type": "licensing", "target": "THE MOON"}, {"source": "THE TOWER", "type": "licensing", "target": "THE CHARIOT"}, {"source": "THE TOWER", "type": "licensing", "target": "TEMPERANCE"}, {"source": "THE TOWER", "type": "licensing", "target": "THE STAR"}, {"source": "THE MOON", "type": "licensing", "target": "THE STAR"}, {"source": "THE MOON", "type": "licensing", "target": "THE SUN"}, {"source": "THE EMPEROR", "type": "licensing", "target": "THE EMPRESS"}, {"source": "THE STAR", "type": "licensing", "target": "THE DEVIL"}, {"source": "THE STAR", "type": "licensing", "target": "THE TOWER"}, {"source": "THE STAR", "type": "licensing", "target": "THE MOON"}, {"source": "THE WORLD", "type": "licensing", "target": "THE HERMIT"}, {"source": "THE DEVIL", "type": "licensing", "target": "THE FOOL"}, {"source": "THE DEVIL", "type": "licensing", "target": "THE STAR"}, {"source": "THE HERMIT", "type": "licensing", "target": "THE LOVERS"}, {"source": "THE HERMIT", "type": "licensing", "target": "THE WORLD"}, {"source": "DEATH", "type": "suit", "target": "THE TOWER"}, {"source": "THE EMPRESS", "type": "suit", "target": "THE LOVERS"}, {"source": "THE EMPRESS", "type": "suit", "target": "THE STAR"}, {"source": "STRENGTH", "type": "suit", "target": "THE HANGED MAN"}, {"source": "THE LOVERS", "type": "suit", "target": "THE EMPRESS"}, {"source": "JUDGEMENT", "type": "suit", "target": "THE FOOL"}, {"source": "JUDGEMENT", "type": "suit", "target": "JUSTICE"}, {"source": "THE MAGICIAN", "type": "suit", "target": "THE CHARIOT"}, {"source": "THE HANGED MAN", "type": "suit", "target": "THE FOOL"}, {"source": "THE HANGED MAN", "type": "suit", "target": "THE HIGH PRIESTESS"}, {"source": "THE HANGED MAN", "type": "suit", "target": "STRENGTH"}, {"source": "THE HIEROPHANT", "type": "suit", "target": "THE EMPEROR"}, {"source": "THE CHARIOT", "type": "suit", "target": "THE MAGICIAN"}, {"source": "TEMPERANCE", "type": "suit", "target": "THE WORLD"}, {"source": "THE FOOL", "type": "suit", "target": "THE HANGED MAN"}, {"source": "THE FOOL", "type": "suit", "target": "THE STAR"}, {"source": "THE FOOL", "type": "suit", "target": "JUDGEMENT"}, {"source": "JUSTICE", "type": "suit", "target": "THE EMPEROR"}, {"source": "JUSTICE", "type": "suit", "target": "JUDGEMENT"}, {"source": "THE HIGH PRIESTESS", "type": "suit" ...
#
# var nodes = {};
#
# // Compute the distinct nodes from the links.
# links.forEach(function(link) {
#   link.source = nodes[link.source] || (nodes[link.source] = {name: link.source});
#   link.target = nodes[link.target] || (nodes[link.target] = {name: link.target});
# });
#
# var width = 960,
#     height = 500;
#
# var force = d3.layout.force()
#     .nodes(d3.values(nodes))
#     .links(links)
#     .size([width, height])
#     .linkDistance(60)
#     .charge(-300)
#     .on("tick", tick)
#     .start();
#
# var svg = d3.select("#graph").append("svg")
#     .attr("width", width)
#     .attr("height", height);
#
# // Per-type markers, as they don't inherit styles.
# svg.append("defs").selectAll("marker")
#     .data(["suit", "licensing", "resolved"])
#   .enter().append("marker")
#     .attr("id", function(d) { return d; })
#     .attr("viewBox", "0 -5 10 10")
#     .attr("refX", 15)
#     .attr("refY", -1.5)
#     .attr("markerWidth", 6)
#     .attr("markerHeight", 6)
#     .attr("orient", "auto")
#   .append("path")
#     .attr("d", "M0,-5L10,0L0,5");
#
# var path = svg.append("g").selectAll("path")
#     .data(force.links())
#   .enter().append("path")
#     .attr("class", function(d) { return "link " + d.type; })
#     .attr("marker-end", function(d) { return "url(#" + d.type + ")"; });
#
# var circle = svg.append("g").selectAll("circle")
#     .data(force.nodes())
#   .enter().append("circle")
#     .attr("r", 6)
#     .call(force.drag);
#
# var text = svg.append("g").selectAll("text")
#     .data(force.nodes())
#   .enter().append("text")
#     .attr("x", 8)
#     .attr("y", ".31em")
#     .text(function(d) { return d.name; });
#
# // Use elliptical arc path segments to doubly-encode directionality.
# function tick() {
#   path.attr("d", linkArc);
#   circle.attr("transform", transform);
#   text.attr("transform", transform);
# }
#
# function linkArc(d) {
#   var dx = d.target.x - d.source.x,
#       dy = d.target.y - d.source.y,
#       dr = Math.sqrt(dx * dx + dy * dy);
#   return "M" + d.source.x + "," + d.source.y + "A" + dr + "," + dr + " 0 0,1 " + d.target.x + "," + d.target.y;
# }
#
# function transform(d) {
#   return "translate(" + d.x + "," + d.y + ")";
# }
#
# </script>

# %%
# Creates the element that will receive the graph
HTML('''<div id="graph"></div>''')
# Out:
# <div id="graph"></div>

# %%
# Runs d3 js visualization
HTML(filled_template)
# Out:
# <!DOCTYPE html>
# <meta charset="utf-8">
# <style>
#
# .link {
#   fill: none;
#   stroke: #666;
#   stroke-width: 1.5px;
# }
#
# #licensing {
#   fill: green;
# }
#
# .link.licensing {
#   stroke: green;
# }
#
# .link.resolved {
#   stroke-dasharray: 0,2 1;
# }
#
# circle {
#   fill: #ccc;
#   stroke: #333;
#   stroke-width: 1.5px;
# }
#
# text {
#   font: 10px sans-serif;
#   pointer-events: none;
#   text-shadow: 0 1px 0 #fff, 1px 0 0 #fff, 0 -1px 0 #fff, -1px 0 0 #fff;
# }
#
# </style>
# <body>
# <script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>
# <script>
#
# var links =  [{"source": "DEATH", "type": "licensing", "target": "THE FOOL"}, {"source": "DEATH", "type": "licensing", "target": "THE EMPRESS"}, {"source": "DEATH", "type": "licensing", "target": "JUDGEMENT"}, {"source": "THE EMPRESS", "type": "licensing", "target": "THE EMPEROR"}, {"source": "THE EMPRESS", "type": "licensing", "target": "DEATH"}, {"source": "STRENGTH", "type": "licensing", "target": "THE CHARIOT"}, {"source": "THE LOVERS", "type": "licensing", "target": "THE HIEROPHANT"}, {"source": "THE LOVERS", "type": "licensing", "target": "THE HERMIT"}, {"source": "JUDGEMENT", "type": "licensing", "target": "DEATH"}, {"source": "THE MAGICIAN", "type": "licensing", "target": "THE HIGH PRIESTESS"}, {"source": "THE MAGICIAN", "type": "licensing", "target": "THE HANGED MAN"}, {"source": "THE HANGED MAN", "type": "licensing", "target": "THE MAGICIAN"}, {"source": "THE HANGED MAN", "type": "licensing", "target": "THE CHARIOT"}, {"source": "THE HIEROPHANT", "type": "licensing", "target": "THE FOOL"}, {"source": "THE HIEROPHANT", "type": "licensing", "target": "THE LOVERS"}, {"source": "THE CHARIOT", "type": "licensing", "target": "STRENGTH"}, {"source": "THE CHARIOT", "type": "licensing", "target": "THE HANGED MAN"}, {"source": "THE CHARIOT", "type": "licensing", "target": "THE TOWER"}, {"source": "TEMPERANCE", "type": "licensing", "target": "THE TOWER"}, {"source": "THE FOOL", "type": "licensing", "target": "THE HIEROPHANT"}, {"source": "THE FOOL", "type": "licensing", "target": "DEATH"}, {"source": "THE FOOL", "type": "licensing", "target": "THE DEVIL"}, {"source": "THE HIGH PRIESTESS", "type": "licensing", "target": "THE MAGICIAN"}, {"source": "THE SUN", "type": "licensing", "target": "THE MOON"}, {"source": "THE TOWER", "type": "licensing", "target": "THE CHARIOT"}, {"source": "THE TOWER", "type": "licensing", "target": "TEMPERANCE"}, {"source": "THE TOWER", "type": "licensing", "target": "THE STAR"}, {"source": "THE MOON", "type": "licensing", "target": "THE STAR"}, {"source": "THE MOON", "type": "licensing", "target": "THE SUN"}, {"source": "THE EMPEROR", "type": "licensing", "target": "THE EMPRESS"}, {"source": "THE STAR", "type": "licensing", "target": "THE DEVIL"}, {"source": "THE STAR", "type": "licensing", "target": "THE TOWER"}, {"source": "THE STAR", "type": "licensing", "target": "THE MOON"}, {"source": "THE WORLD", "type": "licensing", "target": "THE HERMIT"}, {"source": "THE DEVIL", "type": "licensing", "target": "THE FOOL"}, {"source": "THE DEVIL", "type": "licensing", "target": "THE STAR"}, {"source": "THE HERMIT", "type": "licensing", "target": "THE LOVERS"}, {"source": "THE HERMIT", "type": "licensing", "target": "THE WORLD"}, {"source": "DEATH", "type": "suit", "target": "THE TOWER"}, {"source": "THE EMPRESS", "type": "suit", "target": "THE LOVERS"}, {"source": "THE EMPRESS", "type": "suit", "target": "THE STAR"}, {"source": "STRENGTH", "type": "suit", "target": "THE HANGED MAN"}, {"source": "THE LOVERS", "type": "suit", "target": "THE EMPRESS"}, {"source": "JUDGEMENT", "type": "suit", "target": "THE FOOL"}, {"source": "JUDGEMENT", "type": "suit", "target": "JUSTICE"}, {"source": "THE MAGICIAN", "type": "suit", "target": "THE CHARIOT"}, {"source": "THE HANGED MAN", "type": "suit", "target": "THE FOOL"}, {"source": "THE HANGED MAN", "type": "suit", "target": "THE HIGH PRIESTESS"}, {"source": "THE HANGED MAN", "type": "suit", "target": "STRENGTH"}, {"source": "THE HIEROPHANT", "type": "suit", "target": "THE EMPEROR"}, {"source": "THE CHARIOT", "type": "suit", "target": "THE MAGICIAN"}, {"source": "TEMPERANCE", "type": "suit", "target": "THE WORLD"}, {"source": "THE FOOL", "type": "suit", "target": "THE HANGED MAN"}, {"source": "THE FOOL", "type": "suit", "target": "THE STAR"}, {"source": "THE FOOL", "type": "suit", "target": "JUDGEMENT"}, {"source": "JUSTICE", "type": "suit", "target": "THE EMPEROR"}, {"source": "JUSTICE", "type": "suit", "target": "JUDGEMENT"}, {"source": "THE HIGH PRIESTESS", "type": "suit" ...
#
# var nodes = {};
#
# // Compute the distinct nodes from the links.
# links.forEach(function(link) {
#   link.source = nodes[link.source] || (nodes[link.source] = {name: link.source});
#   link.target = nodes[link.target] || (nodes[link.target] = {name: link.target});
# });
#
# var width = 960,
#     height = 500;
#
# var force = d3.layout.force()
#     .nodes(d3.values(nodes))
#     .links(links)
#     .size([width, height])
#     .linkDistance(60)
#     .charge(-300)
#     .on("tick", tick)
#     .start();
#
# var svg = d3.select("#graph").append("svg")
#     .attr("width", width)
#     .attr("height", height);
#
# // Per-type markers, as they don't inherit styles.
# svg.append("defs").selectAll("marker")
#     .data(["suit", "licensing", "resolved"])
#   .enter().append("marker")
#     .attr("id", function(d) { return d; })
#     .attr("viewBox", "0 -5 10 10")
#     .attr("refX", 15)
#     .attr("refY", -1.5)
#     .attr("markerWidth", 6)
#     .attr("markerHeight", 6)
#     .attr("orient", "auto")
#   .append("path")
#     .attr("d", "M0,-5L10,0L0,5");
#
# var path = svg.append("g").selectAll("path")
#     .data(force.links())
#   .enter().append("path")
#     .attr("class", function(d) { return "link " + d.type; })
#     .attr("marker-e
